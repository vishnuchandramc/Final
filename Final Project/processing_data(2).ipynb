# %% [markdown]
# # Pre-processing dataset
# Author : Vishnuchandra mc CSB Roll no:45

# %% [markdown]
# **Here is the process of merging all the cleaned CSV files into a single final dataset.**

# %%
import pandas as pd
import glob, os, time
import helper

# %% [markdown]
# step1 : Fetching the cleaned data from directory

# %%
helper.clean_niti_data('./CSV/')
# Out:
# Processed 15 files in 0.4238600730895996 seconds

# %%
files = glob.glob('./PROCESSED/*.csv')

# %% [markdown]
# ## Reading all the files

# %%
data = pd.read_csv('CSV/GDPALL.csv')

# %%
data
# Out:
#     Unnamed: 0                       States     2004-05     2005-06  \
# 0          NaN  Andaman and Nicobar Islands    181264.0    204420.0
# 1          NaN               Andhra Pradesh  13476688.0  14760642.0
# 2          NaN            Arunachal Pradesh    348751.0    375515.0
# 3          NaN                        Assam   5339771.0   5938458.0
# 4          NaN                        Bihar   7778116.0   8249020.0
# 5          NaN                   Chandigarh    850404.0   1018549.0
# 6          NaN                 Chhattisgarh   4786229.0   5338110.0
# 7          NaN                        Delhi  10032452.0  11537425.0
# 8          NaN                          Goa   1271331.0   1432661.0
# 9          NaN                      Gujarat  20337300.0  24473600.0
# 10         NaN                      Haryana   9579512.0  10888457.0
# 11         NaN             Himachal Pradesh   2407658.0   2712735.0
# 12         NaN            Jammu and Kashmir   2730462.0   2991985.0
# ...

# %%
datas = [pd.read_csv(file) for file in files]

# %%
datas[0].tail()
# Out:
#           State  1980-81  1981-82  1982-83  1983-84  1984-85  1985-86  \
# 27  Uttarakhand      NaN      NaN      NaN      NaN      NaN      NaN
# 28  West Bengal    108.9    117.0    169.8    184.3    244.2    274.9
# 29   All States   1225.5   1440.4   1705.4   1963.6   2466.5   2939.7
# 30        Delhi      NaN      NaN      NaN      NaN      NaN      NaN
# 31   Puducherry      NaN      NaN      NaN      NaN      NaN      NaN
#
#     1986-87  1987-88  1988-89  ...  2007-08   2008-09   2009-10   2010-11  \
# 27      NaN      NaN      NaN  ...   1100.0    1190.0    1340.0    1480.0
# 28    333.5    394.1    448.9  ...  11380.0   12070.0   13310.0   13820.0
# 29   4100.8   4897.7   5935.2  ...  99830.0  102950.0  112810.0  124820.0
# 30      NaN      NaN      NaN  ...   2500.0    2510.0    2470.0    2580.0
# 31      NaN      NaN      NaN  ...    220.0     260.0     290.0     330.0
#
#      2011-12   2012-13   2013-14        2014-15      2015-16      2016-17
# ...

# %% [markdown]
# Here we can see that the datas containing missing values.The Data was given for 29 states and 2 Union Territories, from the year 1981 to 2016, some of the data was missing for some of the states, due to the fact that the data was started to be collected at a later period of time, or maybe the state wasn’t even formed in that year, such years need to remove from the data by using remove NA’s in python pandas.

# %%
del datas  #datas created only to show the missing values

# %% [markdown]
# ## Making the Data Set

# %% [markdown]
# Next step is making the data set from remaining 13 files. For this we fetched all the datasets at a time.

# %%
files = glob.glob('./PROCESSED/*.csv')
files
# Out:
# ['./PROCESSED/Interest_Payments.csv',
#  './PROCESSED/Aggregate_Expenditure.csv',
#  './PROCESSED/Aggregate_Receipts.csv',
#  './PROCESSED/Capital_Expenditure.csv',
#  './PROCESSED/Capital_Receipts.csv',
#  './PROCESSED/Fiscal_Deficits.csv',
#  './PROCESSED/Nominal_GSDP_Series.csv',
#  './PROCESSED/Outstanding_Liabilities.csv',
#  './PROCESSED/Own_Tax_Revenues.csv',
#  './PROCESSED/Revenue_Deficits.csv',
#  './PROCESSED/Revenue_Expenditure.csv',
#  './PROCESSED/Revenue_Receipts.csv',
#  './PROCESSED/Social_Sector_Expenditure.csv']

# %%
#Storing in a List
feature_files = ['./PROCESSED/Capital_Receipts.csv',
 './PROCESSED/Aggregate_Receipts.csv',
 './PROCESSED/Social_Sector_Expenditure.csv',
 './PROCESSED/Interest_Payments.csv',
 './PROCESSED/Own_Tax_Revenues.csv',
 './PROCESSED/Fiscal_Deficits.csv',
 './PROCESSED/Outstanding_Liabilities.csv',
 './PROCESSED/Aggregate_Expenditure.csv',
 './PROCESSED/Revenue_Receipts.csv',
 './PROCESSED/Revenue_Expenditure.csv',
 './PROCESSED/Revenue_Deficits.csv',
 './PROCESSED/Capital_Expenditure.csv']

# %%
target_file = './PROCESSED/Nominal_GSDP_Series.csv'

# %% [markdown]
# ## Features File

# %% [markdown]
# * Next step is setting feature values in the 13 csv files.
# * filename is splicing from the extenstion and using as feature for resultant CSV

# %%
finalDF = pd.DataFrame()
for file in feature_files:
    colname = os.path.splitext(os.path.basename(file))[0]
    
    mydata = pd.read_csv(file)
    mydata = mydata.drop(29)
    series = pd.Series([],dtype=pd.StringDtype()) 
    for col in mydata.iloc[:, 1:-1]:
        series = series.append(pd.Series(mydata[col].values), ignore_index=True)
    finalDF[colname] = series

# %%
finalDF.head()
# Out:
#    Capital_Receipts  Aggregate_Receipts  Social_Sector_Expenditure  \
# 0             325.0              1590.0                      532.0
# 1               NaN                 NaN                        NaN
# 2             187.0               709.0                      171.0
# 3             702.0              1690.0                      452.0
# 4               NaN                 NaN                        NaN
#
#    Interest_Payments  Own_Tax_Revenues  Fiscal_Deficits  \
# 0               81.7             582.0            222.1
# 1                NaN               NaN              NaN
# 2               30.0              66.0            -27.4
# 3              107.1             277.0            335.8
# 4                NaN               NaN              NaN
#
#    Outstanding_Liabilities  Aggregate_Expenditure  Revenue_Receipts  \
# 0                    81.50                 1610.0            1265.0
# 1                     2.80                    NaN               NaN
# ...

# %% [markdown]
# ## Creation target CSV files

# %% [markdown]
# Process of merging resultant dataset into a single dataset

# %%
file = target_file
colname = os.path.splitext(os.path.basename(file))[0]

mydata = pd.read_csv(file)
mydata = mydata.drop(31)

series = pd.Series([],dtype=pd.StringDtype())
for col in mydata.iloc[:, 1:-1]:
    series = series.append(pd.Series(mydata[col].values), ignore_index=True)

finalDF[colname] = series

# %%
finalDF.head()
# Out:
#    Capital_Receipts  Aggregate_Receipts  Social_Sector_Expenditure  \
# 0             325.0              1590.0                      532.0
# 1               NaN                 NaN                        NaN
# 2             187.0               709.0                      171.0
# 3             702.0              1690.0                      452.0
# 4               NaN                 NaN                        NaN
#
#    Interest_Payments  Own_Tax_Revenues  Fiscal_Deficits  \
# 0               81.7             582.0            222.1
# 1                NaN               NaN              NaN
# 2               30.0              66.0            -27.4
# 3              107.1             277.0            335.8
# 4                NaN               NaN              NaN
#
#    Outstanding_Liabilities  Aggregate_Expenditure  Revenue_Receipts  \
# 0                    81.50                 1610.0            1265.0
# 1                     2.80                    NaN               NaN
# ...

# %% [markdown]
# So here we created the target merged dataset. But still it contains null values, so we need to remove all null values to make a perfect dataset for future use

# %% [markdown]
# ## Removing Null values

# %%
finalDF = finalDF.dropna()

# %%
finalDF.head()
# Out:
#    Capital_Receipts  Aggregate_Receipts  Social_Sector_Expenditure  \
# 0             325.0              1590.0                      532.0
# 2             187.0               709.0                      171.0
# 3             702.0              1690.0                      452.0
# 6             345.0              1370.0                      406.0
# 7             116.0               576.0                      137.0
#
#    Interest_Payments  Own_Tax_Revenues  Fiscal_Deficits  \
# 0               81.7             582.0            222.1
# 2               30.0              66.0            -27.4
# 3              107.1             277.0            335.8
# 6               68.6             531.0            246.5
# 7               37.0             234.0            112.0
#
#    Outstanding_Liabilities  Aggregate_Expenditure  Revenue_Receipts  \
# 0                    81.50                 1610.0            1265.0
# 2                    43.41                  758.0             522.0
# ...

# %% [markdown]
# Now we need to store this preprocessed datas into a NITI_DATA.csv file

# %%
finalDF.to_csv('NITI_DATA.csv', index=False)

# %%
finalDF
# Out:
#      Capital_Receipts  Aggregate_Receipts  Social_Sector_Expenditure  \
# 0               325.0              1590.0                      532.0
# 2               187.0               709.0                      171.0
# 3               702.0              1690.0                      452.0
# 6               345.0              1370.0                      406.0
# 7               116.0               576.0                      137.0
# ..                ...                 ...                        ...
# 801           22914.0             68263.0                    20141.0
# 802            2445.0              7982.0                     2781.0
# 803           19349.0             43075.0                    11445.0
# 804           10844.0             21688.0                     4566.0
# 805            1802.0              3604.0                      797.0
#
#      Interest_Payments  Own_Tax_Revenues  Fiscal_Deficits  \
# 0                 81.7             582.0            222.1
# ...

# %% [markdown]
# * So far we done preprocessing or cleaning the data and making feature sets for the future use.Our next step is selecting the effective machine learning model or deep learning model which gives accurate output.
# * Train and test data splitting
# * Prediction
# * Tuning it for increasing the accuracy
# * Final conclusion

# %%
finalDF.describe().T
# Out:
#                            count          mean           std      min  \
# Capital_Receipts           660.0   2428.893939   4110.573309 -5116.00
# Aggregate_Receipts         660.0   7791.672727  10883.932609    38.00
# Social_Sector_Expenditure  660.0   2623.565152   3470.775608     9.00
# Interest_Payments          660.0   1060.228030   1757.027349     0.00
# Own_Tax_Revenues           660.0   2604.877273   4224.076558     0.00
# Fiscal_Deficits            660.0   1630.949848   2688.436374  -360.00
# Outstanding_Liabilities    660.0    417.522303    596.079415     1.42
# Aggregate_Expenditure      660.0   7663.422727  10658.752422    43.00
# Revenue_Receipts           660.0   5362.778788   7044.667651    37.00
# Revenue_Expenditure        660.0   6022.030303   8317.578141    30.00
# Revenue_Deficits           660.0    659.255455   1824.575250 -4328.00
# Capital_Expenditure        660.0   1641.445455   2554.712652    13.00
# ...

# %% [markdown]
# Now this data is ready for future use!
